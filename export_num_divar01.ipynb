# %%
import requests
url='https://api.divar.ir/v5/auth/authenticate'
data={"phone":"09124138533"}
headers={"content-type":"application/json"}
con=requests.session()
con.post(url,json=data,headers=headers)
# Out:
# <Response [200]>

# %%
url='https://api.divar.ir/v5/auth/confirm'
data={"phone":"09124138533" ,"code":"403894"}
headers={"content-type":"application/json"}
res=con.post(url,json=data,headers=headers)
print(res.json())
token=res.json()['token']
authorization=f"Basic {res.json()['token']}"
print(authorization)
# Out:
# {'token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..cyLI9_ubJTD0nm-Zb0FrzkWLlguK2R-W4A6bjaeZg_8', 'access_token': 'eyJhbGciOiJFUzI1NiIsInR5cCI6IkpXVCJ9..u1tfgcPAxp_oe83pZpiF5FccSvhsPJcyJvKqr-hP4N5x8kNwzfl4ff8ZxdofraUOHv0wHcaR7dscv15nSUiksQ', 'refresh_token': 'eyJhbGciOiJFUzI1NiIsInR5cCI6IkpXVCJ9.eyJzaWQiOiIyODczMDJhY
# ...

# %%
print(res.json()['token'])
token=res.json()['token']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(res.json()['token'])
#       2 token=res.json()['token']
#
# KeyError: 'token'

# %%
import uuid
contact_uuid = str(uuid.uuid4())
url='https://api.divar.ir/v8/postcontact/web/contact_info_v2/gZn4ITPT'
data={"contact_uuid":contact_uuid}
headers={'authorization':"Basic eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..cyLI9_ubJTD0nm-Zb0FrzkWLlguK2R-W4A6bjaeZg_8",
         "content-type":"application/json"}
res=con.post(url,json=data,headers=headers)
print(res.json())
# Out:
# {'widget_list': [{'widget_type': 'UNEXPANDABLE_ROW', 'data': {'@type': 'type.googleapis.com/widgets.UnexpandableRowData', 'title': 'شمارهٔ موبایل', 'value': '۰۹۳۶۵۲۲۳۹۸۵', 'action': {'type': 'CALL_PHONE', 'payload': {'@type': 'type.googleapis.com/widgets.CallPhonePayload', 'phone_number': '09365223985'}}, 'compact': True, 'has_copy_to_clipboard': True}, 'action_log': {'server_side_info': {'info': {'@type': 'type.googleapis.com/action_log.ContactInfoInfo', 'post_token': 'gZn4ITPT', 'method_name': 'GetContactWebV2', 'contact_uuid': '9708adcc-b6b6-4dd5-9a13-3fedef79dcac', 'contact_layer_experiment_id': -1}, 'item_type': {'type': 'CONTACT_INFO'}}, 'enabled': True}}, {'widget_type': 'UNEXPANDABLE_ROW', 'data': {'@type': 'type.googleapis.com/widgets.UnexpandableRowData', 'title': 'چت', 'value': 'پیام در چت', 'action': {'type': 'OPEN_POST_CHAT', 'payload': {'@type': 'type.googleapis.com/widgets.OpenPostChatPayload', 'post_token': 'gZn4ITPT'}}, 'compact': True}, 'action_log': {'server_side_i
# ...

# %%
number0=res.json()['widget_list'][0]['data']['value']
number1=res.json()['widget_list'][0]['data']['action']['payload']['phone_number']
print(number0,number1)
# Out:
# ۰۹۳۶۵۲۲۳۹۸۵ 09365223985

# %%
import requests
url='https://api.divar.ir/v8/prediction/w/query'
data={"query":"یدک کش","cities":["715"]}
headers={"content-type":"application/json"}
serche0=requests.post(url,json=data,headers=headers)
print(serche0.json())
suges_len=len(serche0.json()['suggestions'])
print(serche0.json()['suggestions'][0]['ad_count'])
# Out:
# {'suggestions': [{'title': 'یدک کش', 'subtitle': 'در خدمات حمل و نقل', 'display_text': '۲ هزار آگهی', 'search_data': {'form_data': {'data': {'category': {'str': {'value': 'transport'}}, 'districts': {'repeated_string': {}}}}, 'query': 'یدک کش'}, 'change_city': {}, 'probability': 0.93756789, 'ad_count': '2815'}, {'title': 'یدک کش', 'subtitle': 'در خودرو سواری و وانت', 'display_text': '۲۰۰+ آگهی', 'search_data': {'form_data': {'data': {'districts': {'repeated_string': {}}, 'category': {'str': {'value': 'light'}}}}, 'query': 'یدک کش'}, 'change_city': {}, 'probability': 0.0380284, 'ad_count': '200'}, {'title': 'یدک کش', 'subtitle': 'در خدمات موتور و ماشین', 'display_text': '۶۰+ آگهی', 'search_data': {'form_data': {'data': {'districts': {'repeated_string': {}}, 'category': {'str': {'value': 'car-and-motor'}}}}, 'query': 'یدک کش'}, 'change_city': {}, 'probability': 0.00601261482, 'ad_count': '67'}, {'title': 'یدک کش', 'subtitle': 'در قطعات یدکی و لوازم جانبی', 'display_text': '۸۰+ آگهی', '
# ...

# %%
import requests
url='https://api.divar.ir/v8/postlist/w/search'
data={"city_ids":["715"],
       "source_view":"SEARCH_BAR_QUERY_SUGGESTION",
       "disable_recommendation":'false',
       "map_state":{"camera_info":{"bbox":{}}},
       "search_data":{"form_data":{"data":{"category":{"str":{"value":"transport"}}}},
                      "server_payload":{"@type":"type.googleapis.com/widgets.SearchData.ServerPayload",
                                        "additional_form_data":{"data":{"sort":{"str":{"value":"sort_date"}}}}},
                                        "query":"یدک کش"}}
headers={"content-type":"application/json"}
serche1=requests.post(url,json=data,headers=headers)
print(serche1.json())
# Out:
# {'list_top_widgets': [{'widget_type': 'POST_LIST_HEADLINE', 'data': {'@type': 'type.googleapis.com/widgets.PostListHeadline', 'text': 'خدمات باربری و حمل بار در کل ایران'}}], 'list_widgets': [{'widget_type': 'POST_ROW', 'data': {'@type': 'type.googleapis.com/widgets.PostRowData', 'title': 'امدادخودرو. یدک کش', 'action': {'type': 'VIEW_POST', 'payload': {'@type': 'type.googleapis.com/widgets.ViewPostPayload', 'token': 'AavVZrWH', 'web_info': {'title': 'امدادخودرو. یدک کش', 'city_persian': 'بجنورد'}}}, 'image_url': 'https://s100.divarcdn.com/static/photo/afra/webp_thumbnail/mcXOmetPRf2NPd4q9azGDg/a474a270-6467-4d5b-bd4e-7fe30ca067d1.jpg.webp', 'bottom_description_text': 'در بجنورد', 'has_chat': True, 'red_text': 'پله شده', 'has_divider': True, 'image_count': 1, 'image_top_left_tag': {'text': 'پله', 'icon': {'image_url_dark': 'https://s100.divarcdn.com/static/imgs/widget-icons/dark/white_primary/v1/stairs.png', 'image_url_light': 'https://s100.divarcdn.com/static/imgs/widget-icons/light
# ...

# %%
print(serche1.json()['action_log']['server_side_info']['info']['tokens'])
last_post_date=serche1.json()['pagination']['data']['last_post_date']
print(last_post_date)
# Out:
# ['AawW73v6', 'QapgezY5', 'AaU_tpt1', 'Aat5lJCW', 'QZBljxrY', 'AaYLBBVw', 'wZTrDyRw', 'Qalgebef', 'AaWZX95X', 'gZstjb9_', 'QaPw0Aja', 'AafTvXKF', 'AZBn17Qb', 'QamYYojq', 'Qaa0tSiB', 'wZZMj8Fo', 'QaNkPND7', 'AavKZetv', 'QakkRBeS', 'QZL2vZmw', 'QaXUhDOZ', 'gZ4QPAcH', 'Qap89PoD', 'AasCo84J']
# 2025-11-28T17:43:28.320657Z
