# %% [markdown]
# ## divar cruling sequenses

# %%
import os,divar_function,importlib,psycopg2
from dotenv import load_dotenv
load_dotenv()
importlib.reload(divar_function)
# Out:
# <module 'divar_function' from 'c:\\Users\\mhoss\\OneDrive\\Desktop\\divar_cruling\\divar_function.py'>

# %% [markdown]
# ### Read privet data

# %%
authorization=os.getenv("authorization01")
phone_number_owner=os.getenv("phone_number_owner01")
DB_PASSWORD=os.getenv("DB_PASSWORD")

# %% [markdown]
# ### Export authorization

# %%
authorization=divar_function.singin_user(phone_number_owner)
print(authorization)

# %% [markdown]
# #### Search quary in divar

# %%
quary='یدکش'
city=['715']
table=divar_function.serch_query(quary,city)
print(table)
# Out:
# +------------+-----------------------------+------------+-------------------+------------+---------------+
# | title      | subtitle                    | query      | value             |   ad_count |   probability |
# +============+=============================+============+===================+============+===============+
# | یدکش       | در خدمات حمل و نقل          | یدکش       | transport         |       3777 |    0.969912   |
# +------------+-----------------------------+------------+-------------------+------------+---------------+
# | یدکش       | در خودرو سواری و وانت       | یدکش       | light             |        113 |    0.00940486 |
# +------------+-----------------------------+------------+-------------------+------------+---------------+
# | یدکش       | در خدمات موتور و ماشین      | یدکش       | car-and-motor     |        174 |    0.00668968 |
# +------------+-----------------------------+------------+-------------------+------------+---------------+
# | یدکش       | در قطعات یدکی و لوازم جانبی | یدکش       | parts-accessories |         97 |    0.00528269 |
# +------------+-----------------------------+------------+-------------------+------------+---------------+
# | نیسان یدکش | در خودرو سواری و وانت       | نیسان یدکش | light             |         80 |    0.00173027 |
# +------------+-----------------------------+------------+-------------------+------------+---------------+

# %% [markdown]
# #### Database Conection

# %%
conn = psycopg2.connect(
    host="localhost",
    database="divar_crul",
    user="Hossein",
    password=DB_PASSWORD,
    port=5432
)

# %% [markdown]
# #### Insert data in database

# %%
query01="CREATE TABLE derivers (id SERIAL PRIMARY KEY,Phone_number TEXT,City TEXT,ads_Link TEXT);"
query02="INSERT INTO derivers (Phone_number, City,ads_Link) VALUES ('', 'َشیراز','abcdefxz-');"
query03="SELECT * FROM derivers"
query04="SELECT current_database(), current_schema();"
query05="DELETE FROM derivers WHERE id = 1;"
query06="SELECT * FROM derivers WHERE City = 'تهران';"
query07="UPDATE derivers SET Phone_number='054321' WHERE ads_Link='hgfjkikjn'"
query08="UPDATE derivers SET Phone_number='0987654321' WHERE id=1"
query09="INSERT INTO derivers (id,Phone_number, City,ads_Link) VALUES (1,'', 'کرج','abcknloxz');"
query10="UPDATE derivers "
List_ricord=[( '09100000000', 'تهران', 'abcdef-g'),('09100890110', 'قم', 'aocdef-g')]
query11=f"INSERT INTO derivers (Phone_number, City,ads_Link) VALUES  {List_ricord};".replace('[','').replace(']','')
query12="INSERT INTO derivers ( City,ads_Link) VALUES ( 'قزوین','hgfjkikjn');"
query13="DROP TABLE derivers"
query14="INSERT INTO derivers (City,ads_Link) VALUES ( 'َشیراز','abcexz-') ON CONFLICT (ads_Link) DO NOTHING;"
query15="ALTER TABLE derivers ADD CONSTRAINT unique_ads_Link UNIQUE (ads_Link);"
quary16="SELECT * FROM derivers WHERE Phone_number IS NOT NULL"

# %%
cur = conn.cursor()

try:
    cur.execute(quary16)
    conn.commit()   # اگر INSERT / UPDATE / CREATE
    rows=cur.fetchall()
    print(len(rows),rows)
    char='u'
    ro=[row for row in rows if char in row[1]]
    print(ro)
    for r in ro:
        num=r[1].replace(char,'')
        cur.execute(f"UPDATE derivers SET Phone_number='{num}' WHERE id={r[0]}")
s'), (519, '09382896642', 'خوی', 'Qaj4fMO6'), (520, '09170752938', 'شیراز', 'Aazn9Qsa'), (522, '09132386604', 'اصفهان', 'Qa1Fb3w8'), (523, '09908814671', 'شیراز', 'QaIRh8La'), (524, '09176040270', 'شیراز', 'wZ-wD9W6'), (526, '09398610961', 'تهران', 'Qa_pBG2c'), (527, '09179985004', 'شیراز', 'QZBWnvgK'), (529, '09188080981', 'سنندج', 'AaYLBBVw'), (530, '09180162641', 'کرمانشاه', 'Qa4lJfWi'), (532, '09390775603', 'سلماس', 'QaEQjZDS'), (534, '09156741655', 'زاهدان', 'QaYdh_SQ'), (535, '09139809266', 'شهرکرد', 'AaaN0LGt'), (536, '09142247963', 'جلفا', 'QaIeknhY'), (537, '09109616151', 'قم', 'Qawl2Vtv'), (539, '09050201266', 'تبریز', 'QaXxrNhI'), (540, '09144035324', 'تبریز', 'AamVUOMY'), (541, '09184984543', 'همدان', 'QaXl3ynX'), (543, '09196138725', 'شاهرود', 'QaIa0IGW'), (546, '09386501012', 'مشهد', 'wZL-Xkfl'), (547, '09153900142', 'مشهد', 'QaDGIwh5'), (548, '04433846089', 'ارومیه', 'QaLshSWA'), (549, '09023109878', 'اهواز', 'AaVSQEfJ'), (551, '09053283986', 'شیراز', 'QaG6zmp8'), (552, '09184035838', 'سنندج', 'Qa7Uhbw-'), (553, '09174132911', 'شیراز', 'QaXh_eyZ'), (554, '09143403114', 'ارومیه', 'wZYRhUP6'), (555, '09158369035', 'مشهد', 'wZkvVuQc'), (556, '09385598593', 'مشهد', 'QaHBLTD-'), (557, '09381834898', 'شهریار', 'Qap9At0J'), (559, '09189828117', 'سنندج', 'AaTKJBYW'), (560, '09906030113', 'پرند', 'QaSlwnSG'), (562, '09378054692', 'کرج', 'QaQMv_Jk'), (563, '09378522961', 'تهران', 'AaKLYC4V'), (564, '09900071912', 'مشهد', 'Aabc ...
# []

# %% [markdown]
# #### Export ads token

# %%
quary='یدکش'
city=['715']
category="transport"
data_serch=divar_function.ads_export_all(quary,city,category,24)
# Out:
# 2026-02-09T06:46:51.552648Z

# %%
print(len(set(data_serch['City'])),len(set(data_serch['tokens'])))
print(data_serch['City'],data_serch['tokens'])
# Out:
# 16 26
# ['اهواز', 'شیراز', 'ملارد', 'مشهد', 'یاسوج', 'کرمان', 'مشهد', 'زنجان', 'مشهد', 'مشهد', 'شهریار', 'طالقان', 'گرگان', 'کرج', 'شهریار', 'اهواز', 'ارومیه', 'همدان', 'تبریز', 'شیراز', 'بندرعباس', 'تهران', 'کرمان', 'مشهد', 'ارومیه', 'اهواز'] ['AaNKuyBg', 'Qa3V3BGU', 'QatE-Fpk', 'AaF3w1IK', 'wZ4P83tO', 'QY5UGsFL', 'Aay-Ju-q', 'Aaj9vbKJ', 'Qap1Gik5', 'wZDH_HpQ', 'QawZ-Vt_', 'QanVbL_K', 'QaJYJxdT', 'Aa_3885M', 'Qan1UzTj', 'QaPJ2MOV', 'AaYjByxU', 'AacPyUSm', 'Aai-vlnj', 'QZ-650Hx', 'wZno1drg', 'AacOCZJU', 'AaVdw34t', 'QZGbSFfZ', 'QaQYJz7I', 'wZyFXipp']

# %%
divar_function.insert_over_search(conn,data_serch)

# %% [markdown]
# #### Remove bad records

# %%
print(divar_function.cleanup_expired(conn))

# %% [markdown]
# #### Export phon number and Record in Database

# %%
divar_function.export_number(conn,authorization,phone_number_owner)
# Out:
# 09135618605
# User is closed window
# number of phon_number export = 93
